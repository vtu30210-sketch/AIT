# %%
target =10
current = 2
#while current! = target;
print("current state:",current)
if current<target:
  current = current + 1
else:
  current = 1
print("goal reached:", current)
# Out:
# current state: 2
# goal reached: 3
